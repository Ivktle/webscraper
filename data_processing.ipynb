# %%
import pandas as pd

# %%
df_items = pd.read_csv('C:/Users/Oktyabrina/Desktop/webscraper/product.csv')
df_review = pd.read_csv('C:/Users/Oktyabrina/Desktop/webscraper/review.csv')

df_items.to_excel('product.xlsx',
                  sheet_name='Sheet1')
df_review.to_excel('review.xlsx',
                  sheet_name='Sheet1')

# %%
df_review
# Out:
#                       Автор Статус заказа                        Дата отзыва  \
# 0                       NaN           NaN                                NaN
# 1    Покупатель Wildberries      Выкупили                     Сегодня, 15:26
# 2                     Ольга      Выкупили                     Сегодня, 15:16
# 3                  Светлана      Выкупили                     07 июля, 20:44
# 4                   Татьяна      Выкупили                     07 июля, 13:07
# ..                      ...           ...                                ...
# 641  Покупатель Wildberries           NaN  12 октября 2024, 16:03 • Дополнен
# 642               Екатерина           NaN              13 апреля 2024, 12:27
# 643  Покупатель Wildberries           NaN              08 апреля 2024, 05:14
# 644               Валентина    Отказались                   11 января, 14:44
# 645                  Мадина      Выкупили              16 ноября 2024, 10:11
#
#     Кол-во звезд                                       Текст отзыва  \
# 0            NaN                                                NaN
# 1          star5                    Достоинства:Просто понравилась.
# 2          star5                                            Хорошая
# 3          star5  Достоинства:Давно пользуемся этой пастой, очен...
# 4          star5                          Достоинства:Хорошая паста
# ..           ...                                                ...
# 641        star5  Отправила оотзыв не на тот товар, не знаю как ...
# 642        star5  единственный ополаскиватель. после ктр не хоче...
# 643        star5  Доставка долго, но все норм. Хороший товар. Пр...
# 644        star1  Недостатки:Разорвана не только заводская упако...
# 645        star5                 Достоинства:👍🏻 буду заказывать ещё
#
#          Артикул
# 0            NaN
# 1     24716555.0
# 2     24716555.0
# 3     24716555.0
# 4     24716555.0
# ..           ...
# 641  212876972.0
# 642  212876972.0
# 643  212876972.0
# 644  227510622.0
# 645  227510622.0
#
# [646 rows x 6 columns]
